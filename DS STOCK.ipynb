# %%
#stock prediction

# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline
start=datetime.datetime(2006,1,1)
end=datetime.datetime(2016,1,1)
BAC=data.DataReader('BAC','google',start,end)
BAC
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [3], in <cell line: 8>()
#       6 start=datetime.datetime(2006,1,1)
#       7 end=datetime.datetime(2016,1,1)
# ----> 8 BAC=data.DataReader('BAC','google',start,end)
#       9 BAC
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas_datareader\data.py:367, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     365 if data_source not in expected_source:
#     366     msg = "data_source=%r is not implemented" % data_source
# --> 367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
# ...

# %%
pip install --upgrade pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import datetime

start = datetime.datetime(2006, 1, 1)
end = datetime.datetime(2016, 1, 1)

# 'BAC' is the ticker symbol for Bank of America
BAC = yf.download('BAC', start=start, end=end)
AAPL = yf.download('AAPL', start=start, end=end)
MSFT = yf.download('MSFT', start=start, end=end)
AMZN= yf.download('AMZN', start=start, end=end)
TSLA= yf.download('TSLA', start=start, end=end)
KO= yf.download('KO', start=start, end=end)
print(KO)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  20.395000  20.495001  20.174999  20.450001  11.808969  13640800
# 2006-01-04  20.495001  20.535000  20.330000  20.410000  11.785873  19993200
# 2006-01-05  20.360001  20.565001  20.290001  20.510000  11.843618  16613000
# 2006-01-06  20.530001  20.780001  20.430000  20.705000  11.956223  17122800
# 2006-01-09  20.745001  20.834999  20.625000  20.805000  12.013970  13819600
# ...               ...        ...        ...        ...        ...       ...
# ...

# %%
del BAC['Adj Close']

# %%
BAC
# Out:
#                  Open       High        Low      Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  15619400
# ...               ...        ...        ...        ...       ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000  29369400
# 2015-12-28  17.219999  17.230000  16.980000  17.129999  41777500
# 2015-12-29  17.250000  17.350000  17.160000  17.280001  45670400
# 2015-12-30  17.200001  17.240000  17.040001  17.049999  35066400
# 2015-12-31  17.010000  17.070000  16.830000  16.830000  47153000
#
# [2517 rows x 5 columns]

# %%
tickers=['BAC','AAPL','MSFT','AMZN','TSLA','KO']
tickers
# Out:
# ['BAC', 'AAPL', 'MSFT', 'AMZN', 'TSLA', 'KO']

# %%
bank_stocks=pd.concat([BAC,AAPL,MSFT,AMZN,TSLA,KO],axis=1,keys=tickers)
bank_stocks.head()
# Out:
#                   BAC                                                 AAPL  \
#                  Open       High        Low      Close    Volume      Open
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  16296700  2.585000
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  17757900  2.683214
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  14970700  2.672500
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  12599800  2.687500
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  15619400  2.740357
#
#                                                     ... TSLA                  \
#                 High       Low     Close Adj Close  ...  Low Close Adj Close
# Date                                                ...
# 2006-01-03  2.669643  2.580357  2.669643  2.263002  ...  NaN   NaN       NaN
# 2006-01-04  2.713571  2.660714  2.677500  2.269662  ...  NaN   NaN       NaN
# ...

# %%
bank_stocks.columns.names=['BankTicker','StockInFo']
bank_stocks
# Out:
# BankTicker        BAC                                                  AAPL  \
# StockInFo        Open       High        Low      Close    Volume       Open
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  16296700   2.585000
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  17757900   2.683214
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  14970700   2.672500
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  12599800   2.687500
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  15619400   2.740357
# ...               ...        ...        ...        ...       ...        ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000  29369400  27.250000
# 2015-12-28  17.219999  17.230000  16.980000  17.129999  41777500  26.897499
# 2015-12-29  17.250000  17.350000  17.160000  17.280001  45670400  26.740000
# 2015-12-30  17.200001  17.240000  17.040001  17.049999  35066400  27.145000
# ...

# %%
for tick in tickers:
    print(tick,bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# AAPL 33.25
# MSFT 56.54999923706055
# AMZN 34.69850158691406
# TSLA 19.069332122802734
# KO 44.83000183105469

# %%
bank_stocks.xs(key='Close',axis=1,level='StockInFo').max()
# Out:
# BankTicker
# BAC     54.900002
# AAPL    33.250000
# MSFT    56.549999
# AMZN    34.698502
# TSLA    19.069332
# KO      44.830002
# dtype: float64

# %%
returns=pd.DataFrame()
for tick in tickers:
    returns[tick +' Return']=bank_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             BAC Return  AAPL Return  MSFT Return  AMZN Return  TSLA Return  \
# Date
# 2006-01-03         NaN          NaN          NaN          NaN          NaN
# 2006-01-04   -0.010620     0.002943     0.004843    -0.006936          NaN
# 2006-01-05    0.001288    -0.007870     0.000742     0.008466          NaN
# 2006-01-06   -0.001501     0.025813    -0.002964     0.004617          NaN
# 2006-01-09    0.000644    -0.003277    -0.001858    -0.016503          NaN
#
#             KO Return
# Date
# 2006-01-03        NaN
# 2006-01-04  -0.001956
# 2006-01-05   0.004900
# 2006-01-06   0.009508
# 2006-01-09   0.004830

# %%
import seaborn as sns
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# BAC Return    2009-01-20
# AAPL Return   2008-09-29
# MSFT Return   2009-01-22
# AMZN Return   2006-07-26
# TSLA Return   2012-01-13
# KO Return     2008-10-09
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return    2009-04-09
# AAPL Return   2008-10-13
# MSFT Return   2008-10-13
# AMZN Return   2007-04-25
# TSLA Return   2013-05-09
# KO Return     2008-10-13
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC Return     0.036647
# AAPL Return    0.021599
# MSFT Return    0.017764
# AMZN Return    0.026638
# TSLA Return    0.034600
# KO Return      0.011741
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return     0.016163
# AAPL Return    0.016841
# MSFT Return    0.017801
# AMZN Return    0.021147
# TSLA Return    0.024470
# KO Return      0.009011
# dtype: float64

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['TSLA Return'],kde=False,bins=10)
# Out:
# C:\Users\TATA BHARATH YADAV\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TSLA Return'>

# %%
returns.loc['2008-01-01':'2008-12-31'].std()
# Out:
# BAC Return     0.062934
# AAPL Return    0.036666
# MSFT Return    0.030544
# AMZN Return    0.041422
# TSLA Return         NaN
# KO Return      0.022367
# dtype: float64

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['KO Return'],kde=False,bins=10)
# Out:
# <AxesSubplot:xlabel='KO Return'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for tick in tickers:
    print(tick,bank_stocks[tick]['Close'].plot(figsize=(20,5)))
plt.legend(tickers)
# Out:
# BAC AxesSubplot(0.125,0.2;0.775x0.68)
# AAPL AxesSubplot(0.125,0.2;0.775x0.68)
# MSFT AxesSubplot(0.125,0.2;0.775x0.68)
# AMZN AxesSubplot(0.125,0.2;0.775x0.68)
# TSLA AxesSubplot(0.125,0.2;0.775x0.68)
# KO AxesSubplot(0.125,0.2;0.775x0.68)

# %%
pip install cufflinks
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly
import clufflinks as cf
cf.go_offline()
bank_stocks.xs(key='Close',axis=1,level='StockInFo').iplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 import plotly
# ----> 2 import clufflinks as cf
#       3 cf.go_offline()
#       4 bank_stocks.xs(key='Close',axis=1,level='StockInFo').iplot()
#
# ModuleNotFoundError: No module named 'clufflinks'

# %%
pip install cufflinks
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly
import cufflinks as cf
cf.go_offline()
bank_stocks.xs(key='Close',axis=1,level='StockInFo').iplot()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="08ec81c4-0bfa-48b7-a67e-0d89f7ce7ebd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
BAC['Close'].loc['2008-01-01':'2008-12-31'].rolling(window=30).mean().plot(figsize=(12,4),label='avg')
BAC['Close'].loc['2008-01-01':'2008-12-31'].plot(label='normal')
plt.legend()

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='StockInFo').corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='BankTicker', ylabel='BankTicker'>

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='StockInFo').corr(),annot=True)

# %%
a=bank_stocks.xs(key='Close',axis=1,level='StockInFo').corr()
a.iplot(kind='heatmap')
# Out:
# <div>                            <div id="98a67015-1f46-4360-b4ac-332ffbd6b9a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
